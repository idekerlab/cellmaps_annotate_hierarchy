# %% [markdown]
# https://github.com/leahvschaffer/U2OS_music_pipeline

# %% [markdown]
# ### Load the MuSIC 2, April 2023 model
#
# https://www.ndexbio.org/viewer/networks/24137326-d962-11ed-b4a3-005056ae23aa

# %%
import os 
home_dir =os.path.expanduser("~")
# %env MODEL_ANNOTATION_ROOT=Projects/U2OS_MuSIC/MuSIC_maps/

os.path.join(home_dir, os.getenv("MODEL_ANNOTATION_ROOT"))
# Out:
# env: MODEL_ANNOTATION_ROOT=Projects/U2OS_MuSIC/MuSIC_maps/
# '/cellar/users/mhu/Projects/U2OS_MuSIC/MuSIC_maps/'

# %%
import os
import json
from file_io import get_model_directory_path

# %env MODEL_ANNOTATION_ROOT=Projects/cellmaps_annotate_hierarchy/cellmaps_annotate_hierarchy/

model_name = "MuSIC2_Maps"
version = "v1.1_April2023"
model_cx2_filename = "MuSIC2_v1.1_April2023.cx2"
print(get_model_directory_path(model_name, version))

model_path = os.path.join(get_model_directory_path(model_name, version), model_cx2_filename)

with open(model_path, encoding='utf-8') as f:
    data = f.read()
    model = json.loads(data)
# print(model)
# Out:
# env: MODEL_ANNOTATION_ROOT=Projects/cellmaps_annotate_hierarchy/cellmaps_annotate_hierarchy/
# /cellar/users/mhu/Projects/cellmaps_annotate_hierarchy/cellmaps_annotate_hierarchy/MuSIC2_Maps/v1.1_April2023

# %% [markdown]
# ### Select the system

# %%
from file_io import write_system_json, get_root_path
from model_cx2 import get_system, get_genes

system_name = "Cluster3-38"
system = get_system(model, system_name)
# system
write_system_json(system, model_name, version, system_name, "data", get_root_path())
genes = get_genes(system)
print(f'{system_name}: {genes}')
for gene in genes:
    print(gene)
# Out:
# Cluster3-38: ['ATP5MPL', 'DKK3', 'DMAC2', 'MCM3AP', 'SLC25A25', 'TTC21B', 'TULP2', 'VWA8']
# ATP5MPL
# DKK3
# DMAC2
# MCM3AP
# SLC25A25
# TTC21B
# TULP2
# VWA8

# %% [markdown]
# ### Get HUGO data

# %%
from file_io import write_system_json
from hugo import get_hugo_data

hugo_data = get_hugo_data(system)
# hugo_data
# write_system_json(hugo_data, model_name, version, system_name, "hugo", get_root_path())
# Out:
# getting Hugo data for ATP5MPL
# getting Hugo data for DKK3
# getting Hugo data for DMAC2
# getting Hugo data for MCM3AP
# getting Hugo data for SLC25A25
# getting Hugo data for TTC21B
# getting Hugo data for TULP2
# getting Hugo data for VWA8

# %%
from hugo import get_gene_symbols
from uniprot_mygene import get_uniprot_id

file_path = "./hgnc_genes.tsv"
updated_gene_symbols = get_gene_symbols(file_path, system)
uniprot_ids = get_uniprot_id(updated_gene_symbols)
print(uniprot_ids)
# Out:
# validate Hugo symbol for ATP5MPL
# validate Hugo symbol for DKK3
# validate Hugo symbol for DMAC2
# validate Hugo symbol for MCM3AP
# validate Hugo symbol for SLC25A25
# validate Hugo symbol for TTC21B
# validate Hugo symbol for TULP2
# validate Hugo symbol for VWA8
# {'TULP2': 'O00295', 'VWA8': 'A3KMH1', 'SLC25A25': 'Q6KCM7', 'DMAC2': 'Q9NW81', 'TTC21B': 'Q7Z4L5', 'ATP5MJ': 'P56378', 'DKK3': 'Q9UBP4', 'MCM3AP': 'O60318'}

# %% [markdown]
# ### Get Uniprot Data
# Gathers a protein's function, pathway, disease association, aliases, and summary description data from the uniprot database using its REST api

# %%
from uniprot import get_uniprot_data_for_system
from file_io import read_system_json

hugo_data = read_system_json(model_name, version, system_name, "hugo", get_root_path())
uniprot_data = get_uniprot_data_for_system(system, hugo_data=hugo_data)
write_system_json(uniprot_data, model_name, version, system_name, "uniprot", get_root_path())
# Out:
# gene names: ['COLQ', 'FLT4', 'MYADM', 'NMT2', 'SLC4A2', 'TOR1B']
# gene name = COLQ
# uniprot_ids = ['Q9Y215']
# querying uniprot id Q9Y215
# gene name = FLT4
# uniprot_ids = ['P35916']
# querying uniprot id P35916
# gene name = MYADM
# uniprot_ids = ['Q96S97']
# querying uniprot id Q96S97
# gene name = NMT2
# uniprot_ids = ['O60551']
# querying uniprot id O60551
# gene name = SLC4A2
# uniprot_ids = ['P04920']
# querying uniprot id P04920
# gene name = TOR1B
# uniprot_ids = ['O14657']
# querying uniprot id O14657

# %% [markdown]
# ### Summarized Features
# analyze the information to find features shared between n or more system proteins

# %%
import pandas as pd
from io import StringIO
from file_io import write_system_tsv
from uniprot import summarize_uniprot_features, summarized_uniprot_features_to_tsv

summarized_features = summarize_uniprot_features(uniprot_data)
tsv_data = summarized_uniprot_features_to_tsv(summarized_features)
write_system_tsv(tsv_data, model_name, version, system_name, "uniprot_summary", get_root_path())


tsv_file = StringIO(tsv_data)
df = pd.read_csv(tsv_file, sep='\t')
df
# Out:
#                                 Feature  Number of Genes  \
# 0                       plasma membrane                5
# 1                              membrane                5
# 2                       Disease variant                2
# 3                               cytosol                2
# 4                           ATP binding                2
# ..                                  ...              ...
# 121  endoplasmic reticulum organization                1
# 122       nuclear membrane organization                1
# 123     protein localization to nucleus                1
# 124        response to unfolded protein                1
# 125                    nucleus membrane                1
#
#                                 Genes
# 0     COLQ, FLT4, MYADM, NMT2, SLC4A2
# 1    FLT4, MYADM, NMT2, SLC4A2, TOR1B
# 2                          COLQ, FLT4
# 3                          FLT4, NMT2
# 4                         FLT4, TOR1B
# ..                                ...
# 121                             TOR1B
# 122                             TOR1B
# 123                             TOR1B
# 124                             TOR1B
# 125                             TOR1B
#
# [126 rows x 3 columns]

# %% [markdown]
# ### Create Prompts

# %%
from model_cx2 import get_genes
from io import StringIO
import pandas as pd
from chatgpt_prompts import create_system_prompt_page
from pages import write_system_page, write_model_page, dataframe_to_html_table

def create_music_2_chatGPT_prompt(system, tsv_data, n_genes=2, gene_candidacy_text=''):
    """
    Create a ChatGPT prompt based on the given protein list and TSV data.

    :param protein_list: A list of protein names.
    :param tsv_data: A string containing TSV formatted uniprot summary data.
    :param n_genes: An integer representing the minimum number of genes for a feature to be included.
    :return: A string containing the ChatGPT prompt in HTML format.
    """
    # Read the TSV data into a DataFrame
    tsv_file = StringIO(tsv_data)
    df = pd.read_csv(tsv_file, sep='\t')
    
    protein_list = get_genes(system)

    # Generate the ChatGPT prompt in HTML format
    prompt_text = f"Your response should be formatted as HTML paragraphs"
    prompt_text += f"The following is a system of interacting proteins."
    prompt_text += f' Write a critical analysis of this system, describing your reasoning as you go.'
    prompt_text += f'\nWhat mechanisms and biological processes are performed by this system?'
    prompt_text += f'\nWhat cellular components and complexes are involved in this system?'
    prompt_text += f"\nDiscuss potential names for the system. Select the best name and place it in a paragraph at the beginning of your output?"
    prompt_text += f'\nProteins: '
    prompt_text += ", ".join(protein_list) + ".\n\n"
    prompt_text += f"\nA critical goal of the analysis is to determine what, if any, relationship this system has to cancer, and specifically to pediatric cancer" #or osteosarcoma
    prompt_text += f'\n\nSystem features from a Uniprot analysis: \n'
    
    prompt_text = add_uniprot_feature_summary(prompt_text, df)

    prompt = f"<div class='code-section'><button class='copy-prompt-button' onclick='copyPrompt()'>Copy Prompt</button>"
    prompt += f"<pre><code id='prompt-code'>{prompt_text}</code></pre></div>"
    prompt += "<script>function copyPrompt() {var copyText = document.getElementById('prompt-code').innerText; navigator.clipboard.writeText(copyText);}</script>"
    return prompt

def add_uniprot_feature_summary(prompt_text, feature_dataframe, n_genes=2):
    for index, row in feature_dataframe.iterrows():
        number_of_genes = 0
        if row['Number of Genes'] is not None:
            number_of_genes = int(row['Number of Genes'])
        if number_of_genes >= n_genes:
            prompt_text += f"{row['Feature']}: {row['Number of Genes']} proteins: {row['Genes']}\n"
    return prompt_text

            
def create_music_2_system_analysis_page(system_name, tsv_data, n_genes=2):
    # Read the TSV data into a DataFrame
    tsv_file = StringIO(tsv_data)
    df = pd.read_csv(tsv_file, sep='\t')

    # Filter the DataFrame based on the n_genes criterion
    df = df[df['Number of Genes'] >= n_genes]
    
    uniprot_table = dataframe_to_html_table(df)

    # Create the ChatGPT analysis section with a placeholder for the analysis text
    chatgpt_analysis = "<h2>ChatGPT 4 Analysis</h2>\n<p>Paste ChatGPT analysis here:</p>\n<!-- Analysis goes here -->"

    # Create the HTML page with the system summary
    page_title = f"{system_name} Analysis"
    html_page = f"<!DOCTYPE html>\n<html>\n<head>\n<title>{page_title}</title>\n</head>\n<body>\n<h1>{system_name} System Summary</h1>\n<h2>Proteins</h2>\n<p>{', '.join(get_genes(system))}</p>\n<h2>UniProt Data</h2>\n{uniprot_table}\n{chatgpt_analysis}\n</body>\n</html>"

    return html_page

prompt = create_music_2_chatGPT_prompt(system, tsv_data)
prompt_page = create_system_prompt_page(system_name, prompt)
write_system_page(prompt_page, model_name, version, system_name, "chatgpt_prompt", get_root_path())
analysis_page = create_music_2_system_analysis_page(system_name, tsv_data)
write_system_page(analysis_page, model_name, version, system_name, "analysis", get_root_path())
# update the model page to include links to the new pages
write_model_page(model_name, version, get_root_path())

# %% [markdown]
# # TEST THE CREATE PROMPT PYTHON FILE

# %%
workdir = 'Projects/cellmaps_annotate_hierarchy/cellmaps_annotate_hierarchy/'
sig_sys_txt = '/cellar/users/mhu/Projects/U2OS_MuSIC/Mutation/hisig_res/April2023_V1.1/pan_pediatric/042623_sig_systems_q0.3.txt'

# %run create_prompt_for_MuSIC2.py $workdir $sig_sys_txt
# Out:
# /cellar/users/mhu/Projects/cellmaps_annotate_hierarchy/cellmaps_annotate_hierarchy/MuSIC2_Maps/v1.1_April2023
# getting Hugo data for CRY1
# getting Hugo data for CSNK1D
# getting Hugo data for FBXL17
# getting Hugo data for FBXL19
# getting Hugo data for FBXO11
# getting Hugo data for FBXO46
# getting Hugo data for FBXW2
# getting Hugo data for FBXW9
# getting Hugo data for KDM2A
# getting Hugo data for LZTR1
# getting Hugo data for MDM4
# getting Hugo data for SKP1
# getting Hugo data for TP53
# gene names: ['CRY1', 'CSNK1D', 'FBXL17', 'FBXL19', 'FBXO11', 'FBXO46', 'FBXW2', 'FBXW9', 'KDM2A', 'LZTR1', 'MDM4', 'SKP1', 'TP53']
# gene name = CRY1
# uniprot_ids = ['Q16526']
# querying uniprot id Q16526
# gene name = CSNK1D
# uniprot_ids = ['P48730']
# querying uniprot id P48730
# gene name = FBXL17
# uniprot_ids = ['Q9UF56']
# querying uniprot id Q9UF56
# gene name = FBXL19
# uniprot_ids = ['Q6PCT2']
# querying uniprot id Q6PCT2
# gene name = FBXO11
# uniprot_ids = ['Q86XK2']
# querying uniprot id Q86XK2
# gene name = FBXO46
# uniprot_ids = ['Q6PJ61']
# querying uniprot id Q6PJ61
# gene name = FBXW2
# uniprot_ids = ['Q9UKT8']
# querying uniprot id Q9UKT8
# gene name = FBXW9
# uniprot_ids = ['Q5XUX1']
# querying uniprot id Q5XUX1
# gene name = KDM2A
# uniprot_ids = ['Q9Y2K7']
# querying uniprot id Q9Y2K7
# gene name = LZTR1
# uniprot_ids = ['Q8N653']
# querying uniprot id Q8N653
# gene name = MDM4
# uniprot_ids = ['O15151']
# querying uniprot id O15151
# gene name = SKP1
# uniprot_ids = ['P63208']
# querying uniprot id P63208
# gene name = TP53
# uniprot_ids = ['P04637']
# querying uniprot id P04637
# getting Hugo data for ACTL6A
# getting Hugo data for ARID1A
# getting Hugo data for ARID1B
# getting Hugo data for ARID2
# getting Hugo data for BCL7A
# getting Hugo data for BCL7B
# getting Hugo data for BCL7C
# getting Hugo data for BICRA
# getting Hugo data for BICRAL
# getting Hugo data for BOD1L1
# getting Hugo data for BRCC3
# getting Hugo data for BRD7
# getting Hugo data for BRD9
# getting Hugo data for C17orf49
# getting Hugo data for CDCA7
# getting Hugo data for CHD8
# getting Hugo data for CTDSPL2
# getting Hugo data for DPF1
# getting Hugo data for DPF2
# getting Hugo data for ERCC4
# getting Hugo data for KPNA1
# getting Hugo data for KPNA2
# getting Hugo data for NIPBL
# getting Hugo data for NOP58
# getting Hugo data for NUP50
# getting Hugo data for PBRM1
# getting Hugo data for PHAX
# getting Hugo data for RAMAC
# getting Hugo data for SMARCA2
# getting Hugo data for SMARCA4
# getting Hugo data for SMARCB1
# getting Hugo data for SMARCC1
# getting Hugo data for SMARCC2
# getting Hugo data for SMARCD1
# getting Hugo data for SMARCD2
# getting Hugo data for SMARCD3
# getting Hugo data for SMARCE1
# getting Hugo data for SRCAP
# getting Hugo data for SRRT
# getting Hugo data for SS18L1
# getting Hugo data for TCERG1
# gene names: ['ACTL6A', 'ARID1A', 'ARID1B', 'ARID2', 'BCL7A', 'BCL7B', 'BCL7C', 'BICRA', 'BICRAL', 'BOD1L1', 'BRCC3', 'BRD7', 'BRD9', 'C17orf49', 'CDCA7', 'CHD8', 'CTDSPL2', 'DPF1', 'DPF2', 'ERCC4', 'KPNA1', 'KPNA2', 'NIPBL', 'NOP58', 'NUP50', 'PBRM1', 'PHAX', 'RAMAC', 'SMARCA2', 'SMARCA4', 'SMARCB1', 'SMARCC1', 'SMARCC2', 'SMARCD1', 'SMARCD2', 'SMARCD3', 'SMARCE1', 'SRCAP', 'SRRT', 'SS18L1', 'TCERG1']
# gene name = ACTL6A
# uniprot_ids = ['O96019']
# querying uniprot id O96019
# gene name = ARID1A
# uniprot_ids = ['O14497']
# querying uniprot id O14497
# gene name = ARID1B
# uniprot_ids = ['Q8NFD5']
# querying uniprot id Q8NFD5
# gene name = ARID2
# uniprot_ids = ['Q68CP9']
# querying uniprot id Q68CP9
# gene name = BCL7A
# uniprot_ids = ['Q4VC05']
# querying uniprot id Q4VC05
# gene name = BCL7B
# uniprot_ids = ['Q9BQE9']
# querying uniprot id Q9BQE9
# gene name = BCL7C
# uniprot_ids = ['Q8WUZ0']
# querying uniprot id Q8WUZ0
# gene name = BICRA
# uniprot_ids = ['Q9NZM4']
# querying uniprot id Q9NZM4
# gene name = BICRAL
# uniprot_ids = ['Q6AI39']
# querying uniprot id Q6AI39
# gene name = BOD1L1
# uniprot_ids = ['Q8NFC6']
# querying uniprot id Q8NFC6
# gene name = BRCC3
# uniprot_ids = ['P46736']
# querying uniprot id P46736
# gene name = BRD7
# uniprot_ids = ['Q9NPI1']
# querying uniprot id Q9NPI1
# gene name = BRD9
# uniprot_ids = ['Q9H8M2']
# querying uniprot id Q9H8M2
# gene name = C17orf49
# uniprot_ids = ['Q8IXM2']
# querying uniprot id Q8IXM2
# gene name = CDCA7
# uniprot_ids = ['Q9BWT1']
# querying uniprot id Q9BWT1
# gene name = CHD8
# uniprot_ids = ['Q9HCK8']
# querying uniprot id Q9HCK8
# gene name = CTDSPL2
# uniprot_ids = ['Q05D32']
# querying uniprot id Q05D32
# gene name = DPF1
# uniprot_ids = ['Q92782']
# querying uniprot id Q92782
# gene name = DPF2
# uniprot_ids = ['Q92785']
# querying uniprot id Q92785
# gene name = ERCC4
# uniprot_ids = ['Q92889']
# querying uniprot id Q92889
# gene name = KPNA1
# uniprot_ids = ['P52294']
# querying uniprot id P52294
# gene name = KPNA2
# uniprot_ids = ['P52292']
# querying uniprot id P52292
# gene name = NIPBL
# uniprot_ids = ['Q6KC79']
# querying uniprot id Q6KC79
# gene name = NOP58
# uniprot_ids = ['Q9Y2X3']
# querying uniprot id Q9Y2X3
# gene name = NUP50
# uniprot_ids = ['Q9UKX7']
# querying uniprot id Q9UKX7
# gene name = PBRM1
# uniprot_ids = ['Q86U86']
# querying uniprot id Q86U86
# gene name = PHAX
# uniprot_ids = ['Q9H814']
# querying uniprot id Q9H814
# gene name = RAMAC
# uniprot_ids = ['Q9BTL3']
# querying uniprot id Q9BTL3
# gene name = SMARCA2
# uniprot_ids = ['P51531']
# querying uniprot id P51531
# gene name = SMARCA4
# uniprot_ids = ['P51532']
# querying uniprot id P51532
# gene name = SMARCB1
# uniprot_ids = ['Q12824']
# querying uniprot id Q12824
# gene name = SMARCC1
# uniprot_ids = ['Q92922']
# querying uniprot id Q92922
# gene name = SMARCC2
# uniprot_ids = ['Q8TAQ2']
# querying uniprot id Q8TAQ2
# gene name = SMARCD1
# uniprot_ids = ['Q96GM5']
# querying uniprot id Q96GM5
# gene name = SMARCD2
# uniprot_ids = ['Q92925']
# querying uniprot id Q92925
# gene name = SMARCD3
# uniprot_ids = ['Q6STE5']
# querying uniprot id Q6STE5
# gene name = SMARCE1
# uniprot_ids = ['Q969G3']
# querying uniprot id Q969G3
# gene name = SRCAP
# uniprot_ids = ['Q6ZRS2']
# querying uniprot id Q6ZRS2
# gene name = SRRT
# uniprot_ids = ['Q9BXP5']
# querying uniprot id Q9BXP5
# gene name = SS18L1
# uniprot_ids = ['O75177']
# querying uniprot id O75177
# gene name = TCERG1
# uniprot_ids = ['O14776']
# querying uniprot id O14776
# getting Hugo data for ATP5MPL
# getting Hugo data for DKK3
# getting Hugo data for DMAC2
# getting Hugo data for MCM3AP
# getting Hugo data for SLC25A25
# getting Hugo data for TTC21B
# getting Hugo data for TULP2
# getting Hugo data for VWA8
# gene names: ['ATP5MPL', 'DKK3', 'DMAC2', 'MCM3AP', 'SLC25A25', 'TTC21B', 'TULP2', 'VWA8']
# gene name = ATP5MPL
# uniprot_ids = ['P56378']
# querying uniprot id P56378
# gene name = DKK3
# uniprot_ids = ['Q9UBP4']
# querying uniprot id Q9UBP4
# gene name = DMAC2
# uniprot_ids = ['Q9NW81']
# querying uniprot id Q9NW81
# gene name = MCM3AP
# uniprot_ids = ['O60318']
# querying uniprot id O60318
# gene name = SLC25A25
# uniprot_ids = ['Q6KCM7']
# querying uniprot id Q6KCM7
# gene name = TTC21B
# uniprot_ids = ['Q7Z4L5']
# querying uniprot id Q7Z4L5
# gene name = TULP2
# uniprot_ids = ['O00295']
# querying uniprot id O00295
# gene name = VWA8
# uniprot_ids = ['A3KMH1']
# querying uniprot id A3KMH1
# getting Hugo data for CDH2
# getting Hugo data for CDH4
# getting Hugo data for CDH8
# getting Hugo data for CTNNA1
# getting Hugo data for CTNNB1
# getting Hugo data for EPB41L2
# getting Hugo data for PCDH7
# getting Hugo data for PCDHA1
# getting Hugo data for PKP4
# getting Hugo data for SPECC1
# getting Hugo data for TMTC4
# gene names: ['CDH2', 'CDH4', 'CDH8', 'CTNNA1', 'CTNNB1', 'EPB41L2', 'PCDH7', 'PCDHA1', 'PKP4', 'SPECC1', 'TMTC4']
# gene name = CDH2
# uniprot_ids = ['P19022']
# querying uniprot id P19022
# gene name = CDH4
# uniprot_ids = ['P55283']
# querying uniprot id P55283
# gene name = CDH8
# uniprot_ids = ['P55286']
# querying uniprot id P55286
# gene name = CTNNA1
# uniprot_ids = ['P35221']
# querying uniprot id P35221
# gene name = CTNNB1
# uniprot_ids = ['P35222']
# querying uniprot id P35222
# gene name = EPB41L2
# uniprot_ids = ['O43491']
# querying uniprot id O43491
# gene name = PCDH7
# uniprot_ids = ['O60245']
# querying uniprot id O60245
# gene name = PCDHA1
# uniprot_ids = ['Q9Y5I3']
# querying uniprot id Q9Y5I3
# gene name = PKP4
# uniprot_ids = ['Q99569']
# querying uniprot id Q99569
# gene name = SPECC1
# uniprot_ids = ['Q5M775']
# querying uniprot id Q5M775
# gene name = TMTC4
# uniprot_ids = ['Q5T4D3']
# querying uniprot id Q5T4D3
# getting Hugo data for ACVR1B
# getting Hugo data for ANKIB1
# getting Hugo data for BMPR1A
# getting Hugo data for IFNGR1
# getting Hugo data for IFNLR1
# getting Hugo data for LAYN
# getting Hugo data for MYOF
# getting Hugo data for PDGFRB
# getting Hugo data for PIK3CA
# getting Hugo data for PIK3CD
# getting Hugo data for PIK3R1
# getting Hugo data for RNF149
# getting Hugo data for SUSD6
# getting Hugo data for ZDHHC9
# gene names: ['ACVR1B', 'ANKIB1', 'BMPR1A', 'IFNGR1', 'IFNLR1', 'LAYN', 'MYOF', 'PDGFRB', 'PIK3CA', 'PIK3CD', 'PIK3R1', 'RNF149', 'SUSD6', 'ZDHHC9']
# gene name = ACVR1B
# uniprot_ids = ['P36896']
# querying uniprot id P36896
# gene name = ANKIB1
# uniprot_ids = ['Q9P2G1']
# querying uniprot id Q9P2G1
# gene name = BMPR1A
# uniprot_ids = ['P36894']
# querying uniprot id P36894
# gene name = IFNGR1
# uniprot_ids = ['P15260']
# querying uniprot id P15260
# gene name = IFNLR1
# uniprot_ids = ['Q8IU57']
# querying uniprot id Q8IU57
# gene name = LAYN
# uniprot_ids = ['Q6UX15']
# querying uniprot id Q6UX15
# gene name = MYOF
# uniprot_ids = ['Q9NZM1']
# querying uniprot id Q9NZM1
# gene name = PDGFRB
# uniprot_ids = ['P09619']
# querying uniprot id P09619
# gene name = PIK3CA
# uniprot_ids = ['P42336']
# querying uniprot id P42336
# gene name = PIK3CD
# uniprot_ids = ['O00329']
# querying uniprot id O00329
# gene name = PIK3R1
# uniprot_ids = ['P27986']
# querying uniprot id P27986
# gene name = RNF149
# uniprot_ids = ['Q8NC42']
# querying uniprot id Q8NC42
# gene name = SUSD6
# uniprot_ids = ['Q92537']
# querying uniprot id Q92537
# gene name = ZDHHC9
# uniprot_ids = ['Q9Y397']
# querying uniprot id Q9Y397
# getting Hugo data for BCLAF1
# getting Hugo data for BMP2K
# getting Hugo data for BRD2
# getting Hugo data for CDK11A
# getting Hugo data for CDK11B
# getting Hugo data for CHTOP
# getting Hugo data for CWC25
# getting Hugo data for GPATCH8
# getting Hugo data for HBP1
# getting Hugo data for IK
# getting Hugo data for NCBP3
# getting Hugo data for PNN
# getting Hugo data for PPIG
# getting Hugo data for PRPF40A
# getting Hugo data for PRPF4B
# getting Hugo data for RBBP6
# getting Hugo data for RBM15B
# getting Hugo data for RBM25
# getting Hugo data for RSRC2
# getting Hugo data for SETD2
# getting Hugo data for SFSWAP
# getting Hugo data for SON
# getting Hugo data for SRRM2
# getting Hugo data for SRSF11
# getting Hugo data for SRSF4
# getting Hugo data for SRSF6
# getting Hugo data for THRAP3
# getting Hugo data for UNK
# getting Hugo data for WBP11
# getting Hugo data for ZC3H14
# getting Hugo data for ZC3H18
# gene names: ['BCLAF1', 'BMP2K', 'BRD2', 'CDK11A', 'CDK11B', 'CHTOP', 'CWC25', 'GPATCH8', 'HBP1', 'IK', 'NCBP3', 'PNN', 'PPIG', 'PRPF40A', 'PRPF4B', 'RBBP6', 'RBM15B', 'RBM25', 'RSRC2', 'SETD2', 'SFSWAP', 'SON', 'SRRM2', 'SRSF11', 'SRSF4', 'SRSF6', 'THRAP3', 'UNK', 'WBP11', 'ZC3H14', 'ZC3H18']
# gene name = BCLAF1
# uniprot_ids = ['Q9NYF8']
# querying uniprot id Q9NYF8
# gene name = BMP2K
# uniprot_ids = ['Q9NSY1']
# querying uniprot id Q9NSY1
# gene name = BRD2
# uniprot_ids = ['P25440']
# querying uniprot id P25440
# gene name = CDK11A
# uniprot_ids = ['Q9UQ88']
# querying uniprot id Q9UQ88
# gene name = CDK11B
# uniprot_ids = ['P21127']
# querying uniprot id P21127
# gene name = CHTOP
# uniprot_ids = ['Q9Y3Y2']
# querying uniprot id Q9Y3Y2
# gene name = CWC25
# uniprot_ids = ['Q9NXE8']
# querying uniprot id Q9NXE8
# gene name = GPATCH8
# uniprot_ids = ['Q9UKJ3']
# querying uniprot id Q9UKJ3
# gene name = HBP1
# uniprot_ids = ['O60381']
# querying uniprot id O60381
# gene name = IK
# uniprot_ids = ['Q13123']
# querying uniprot id Q13123
# gene name = NCBP3
# uniprot_ids = ['Q53F19']
# querying uniprot id Q53F19
# gene name = PNN
# uniprot_ids = ['Q9H307']
# querying uniprot id Q9H307
# gene name = PPIG
# uniprot_ids = ['Q13427']
# querying uniprot id Q13427
# gene name = PRPF40A
# uniprot_ids = ['O75400']
# querying uniprot id O75400
# gene name = PRPF4B
# uniprot_ids = ['Q13523']
# querying uniprot id Q13523
# gene name = RBBP6
# uniprot_ids = ['Q7Z6E9']
# querying uniprot id Q7Z6E9
# gene name = RBM15B
# uniprot_ids = ['Q8NDT2']
# querying uniprot id Q8NDT2
# gene name = RBM25
# uniprot_ids = ['P49756']
# querying uniprot id P49756
# gene name = RSRC2
# uniprot_ids = ['Q7L4I2']
# querying uniprot id Q7L4I2
# gene name = SETD2
# uniprot_ids = ['Q9BYW2']
# querying uniprot id Q9BYW2
# gene name = SFSWAP
# uniprot_ids = ['Q12872']
# querying uniprot id Q12872
# gene name = SON
# uniprot_ids = ['P18583']
# querying uniprot id P18583
# gene name = SRRM2
# uniprot_ids = ['Q9UQ35']
# querying uniprot id Q9UQ35
# gene name = SRSF11
# uniprot_ids = ['Q05519']
# querying uniprot id Q05519
# gene name = SRSF4
# uniprot_ids = ['Q08170']
# querying uniprot id Q08170
# gene name = SRSF6
# uniprot_ids = ['Q13247']
# querying uniprot id Q13247
# gene name = THRAP3
# uniprot_ids = ['Q9Y2W1']
# querying uniprot id Q9Y2W1
# gene name = UNK
# uniprot_ids = ['Q9C0B0']
# querying uniprot id Q9C0B0
# gene name = WBP11
# uniprot_ids = ['Q9Y2W2']
# querying uniprot id Q9Y2W2
# gene name = ZC3H14
# uniprot_ids = ['Q6PJT7']
# querying uniprot id Q6PJT7
# gene name = ZC3H18
# uniprot_ids = ['Q86VM9']
# querying uniprot id Q86VM9
# getting Hugo data for BTBD1
# getting Hugo data for ENO3
# getting Hugo data for FABP3
# getting Hugo data for HSPB6
# getting Hugo data for KLHL41
# getting Hugo data for LPL
# getting Hugo data for MFGE8
# getting Hugo data for MYH1
# getting Hugo data for MYH15
# getting Hugo data for MYH2
# getting Hugo data for MYH4
# getting Hugo data for MYH6
# getting Hugo data for MYH7
# getting Hugo data for MYH8
# getting Hugo data for MYL3
# getting Hugo data for MYOM3
# getting Hugo data for OBSCN
# getting Hugo data for PLXNA4
# getting Hugo data for PRX
# getting Hugo data for TNNI1
# getting Hugo data for TNNT1
# gene names: ['BTBD1', 'ENO3', 'FABP3', 'HSPB6', 'KLHL41', 'LPL', 'MFGE8', 'MYH1', 'MYH15', 'MYH2', 'MYH4', 'MYH6', 'MYH7', 'MYH8', 'MYL3', 'MYOM3', 'OBSCN', 'PLXNA4', 'PRX', 'TNNI1', 'TNNT1']
# gene name = BTBD1
# uniprot_ids = ['Q9H0C5']
# querying uniprot id Q9H0C5
# gene name = ENO3
# uniprot_ids = ['P13929']
# querying uniprot id P13929
# gene name = FABP3
# uniprot_ids = ['P05413']
# querying uniprot id P05413
# gene name = HSPB6
# uniprot_ids = ['O14558']
# querying uniprot id O14558
# gene name = KLHL41
# uniprot_ids = ['O60662']
# querying uniprot id O60662
# gene name = LPL
# uniprot_ids = ['P06858']
# querying uniprot id P06858
# gene name = MFGE8
# uniprot_ids = ['Q08431']
# querying uniprot id Q08431
# gene name = MYH1
# uniprot_ids = ['P12882']
# querying uniprot id P12882
# gene name = MYH15
# uniprot_ids = ['Q9Y2K3']
# querying uniprot id Q9Y2K3
# gene name = MYH2
# uniprot_ids = ['Q9UKX2']
# querying uniprot id Q9UKX2
# gene name = MYH4
# uniprot_ids = ['Q9Y623']
# querying uniprot id Q9Y623
# gene name = MYH6
# uniprot_ids = ['P13533']
# querying uniprot id P13533
# gene name = MYH7
# uniprot_ids = ['P12883']
# querying uniprot id P12883
# gene name = MYH8
# uniprot_ids = ['P13535']
# querying uniprot id P13535
# gene name = MYL3
# uniprot_ids = ['P08590']
# querying uniprot id P08590
# gene name = MYOM3
# uniprot_ids = ['Q5VTT5']
# querying uniprot id Q5VTT5
# gene name = OBSCN
# uniprot_ids = ['Q5VST9']
# querying uniprot id Q5VST9
# gene name = PLXNA4
# uniprot_ids = ['Q9HCM2']
# querying uniprot id Q9HCM2
# gene name = PRX
# uniprot_ids = ['Q9BXM0']
# querying uniprot id Q9BXM0
# gene name = TNNI1
# uniprot_ids = ['P19237']
# querying uniprot id P19237
# gene name = TNNT1
# uniprot_ids = ['P13805']
# querying uniprot id P13805
# getting Hugo data for AHDC1
# getting Hugo data for ASCC2
# getting Hugo data for BTBD1
# getting Hugo data for DLGAP4
# getting Hugo data for ENAH
# getting Hugo data for ENO3
# getting Hugo data for FABP3
# getting Hugo data for FBXO28
# getting Hugo data for GIT1
# getting Hugo data for HSPB6
# getting Hugo data for KLHL41
# getting Hugo data for LDB3
# getting Hugo data for LPL
# getting Hugo data for LPP
# getting Hugo data for LPXN
# getting Hugo data for LRCH4
# getting Hugo data for MFGE8
# getting Hugo data for MYH1
# getting Hugo data for MYH15
# getting Hugo data for MYH2
# getting Hugo data for MYH4
# getting Hugo data for MYH6
# getting Hugo data for MYH7
# getting Hugo data for MYH8
# getting Hugo data for MYL3
# getting Hugo data for MYOM3
# getting Hugo data for NOB1
# getting Hugo data for OBSCN
# getting Hugo data for PGBD1
# getting Hugo data for PLXNA4
# getting Hugo data for PRX
# getting Hugo data for PTK2
# getting Hugo data for PXN
# getting Hugo data for SDC1
# getting Hugo data for SENP1
# getting Hugo data for TLE2
# getting Hugo data for TLN1
# getting Hugo data for TNNI1
# getting Hugo data for TNNT1
# getting Hugo data for TNS1
# getting Hugo data for TNS3
# getting Hugo data for TRIM62
# getting Hugo data for TRIP6
# getting Hugo data for USP33
# getting Hugo data for VIPR2
# getting Hugo data for ZYX
# gene names: ['AHDC1', 'ASCC2', 'BTBD1', 'DLGAP4', 'ENAH', 'ENO3', 'FABP3', 'FBXO28', 'GIT1', 'HSPB6', 'KLHL41', 'LDB3', 'LPL', 'LPP', 'LPXN', 'LRCH4', 'MFGE8', 'MYH1', 'MYH15', 'MYH2', 'MYH4', 'MYH6', 'MYH7', 'MYH8', 'MYL3', 'MYOM3', 'NOB1', 'OBSCN', 'PGBD1', 'PLXNA4', 'PRX', 'PTK2', 'PXN', 'SDC1', 'SENP1', 'TLE2', 'TLN1', 'TNNI1', 'TNNT1', 'TNS1', 'TNS3', 'TRIM62', 'TRIP6', 'USP33', 'VIPR2', 'ZYX']
# gene name = AHDC1
# uniprot_ids = ['Q5TGY3']
# querying uniprot id Q5TGY3
# gene name = ASCC2
# uniprot_ids = ['Q9H1I8']
# querying uniprot id Q9H1I8
# gene name = BTBD1
# uniprot_ids = ['Q9H0C5']
# querying uniprot id Q9H0C5
# gene name = DLGAP4
# uniprot_ids = ['Q9Y2H0']
# querying uniprot id Q9Y2H0
# gene name = ENAH
# uniprot_ids = ['Q8N8S7']
# querying uniprot id Q8N8S7
# gene name = ENO3
# uniprot_ids = ['P13929']
# querying uniprot id P13929
# gene name = FABP3
# uniprot_ids = ['P05413']
# querying uniprot id P05413
# gene name = FBXO28
# uniprot_ids = ['Q9NVF7']
# querying uniprot id Q9NVF7
# gene name = GIT1
# uniprot_ids = ['Q9Y2X7']
# querying uniprot id Q9Y2X7
# gene name = HSPB6
# uniprot_ids = ['O14558']
# querying uniprot id O14558
# gene name = KLHL41
# uniprot_ids = ['O60662']
# querying uniprot id O60662
# gene name = LDB3
# uniprot_ids = ['O75112']
# querying uniprot id O75112
# gene name = LPL
# uniprot_ids = ['P06858']
# querying uniprot id P06858
# gene name = LPP
# uniprot_ids = ['Q93052']
# querying uniprot id Q93052
# gene name = LPXN
# uniprot_ids = ['O60711']
# querying uniprot id O60711
# gene name = LRCH4
# uniprot_ids = ['O75427']
# querying uniprot id O75427
# gene name = MFGE8
# uniprot_ids = ['Q08431']
# querying uniprot id Q08431
# gene name = MYH1
# uniprot_ids = ['P12882']
# querying uniprot id P12882
# gene name = MYH15
# uniprot_ids = ['Q9Y2K3']
# querying uniprot id Q9Y2K3
# gene name = MYH2
# uniprot_ids = ['Q9UKX2']
# querying uniprot id Q9UKX2
# gene name = MYH4
# uniprot_ids = ['Q9Y623']
# querying uniprot id Q9Y623
# gene name = MYH6
# uniprot_ids = ['P13533']
# querying uniprot id P13533
# gene name = MYH7
# uniprot_ids = ['P12883']
# querying uniprot id P12883
# gene name = MYH8
# uniprot_ids = ['P13535']
# querying uniprot id P13535
# gene name = MYL3
# uniprot_ids = ['P08590']
# querying uniprot id P08590
# gene name = MYOM3
# uniprot_ids = ['Q5VTT5']
# querying uniprot id Q5VTT5
# gene name = NOB1
# uniprot_ids = ['Q9ULX3']
# querying uniprot id Q9ULX3
# gene name = OBSCN
# uniprot_ids = ['Q5VST9']
# querying uniprot id Q5VST9
# gene name = PGBD1
# uniprot_ids = ['Q96JS3']
# querying uniprot id Q96JS3
# gene name = PLXNA4
# uniprot_ids = ['Q9HCM2']
# querying uniprot id Q9HCM2
# gene name = PRX
# uniprot_ids = ['Q9BXM0']
# querying uniprot id Q9BXM0
# gene name = PTK2
# uniprot_ids = ['Q05397']
# querying uniprot id Q05397
# gene name = PXN
# uniprot_ids = ['P49023']
# querying uniprot id P49023
# gene name = SDC1
# uniprot_ids = ['P18827']
# querying uniprot id P18827
# gene name = SENP1
# uniprot_ids = ['Q9P0U3']
# querying uniprot id Q9P0U3
# gene name = TLE2
# uniprot_ids = ['Q04725']
# querying uniprot id Q04725
# gene name = TLN1
# uniprot_ids = ['Q9Y490']
# querying uniprot id Q9Y490
# gene name = TNNI1
# uniprot_ids = ['P19237']
# querying uniprot id P19237
# gene name = TNNT1
# uniprot_ids = ['P13805']
# querying uniprot id P13805
# gene name = TNS1
# uniprot_ids = ['Q9HBL0']
# querying uniprot id Q9HBL0
# gene name = TNS3
# uniprot_ids = ['Q68CZ2']
# querying uniprot id Q68CZ2
# gene name = TRIM62
# uniprot_ids = ['Q9BVG3']
# querying uniprot id Q9BVG3
# gene name = TRIP6
# uniprot_ids = ['Q15654']
# querying uniprot id Q15654
# gene name = USP33
# uniprot_ids = ['Q8TEY7']
# querying uniprot id Q8TEY7
# gene name = VIPR2
# uniprot_ids = ['P41587']
# querying uniprot id P41587
# gene name = ZYX
# uniprot_ids = ['Q15942']
# querying uniprot id Q15942
# getting Hugo data for CDCA5
# getting Hugo data for DBR1
# getting Hugo data for MPLKIP
# getting Hugo data for MYCBP2
# getting Hugo data for PDS5B
# getting Hugo data for PMEPA1
# getting Hugo data for RAD21
# getting Hugo data for SMC1A
# getting Hugo data for SMC3
# getting Hugo data for SPATA20
# getting Hugo data for TSEN54
# getting Hugo data for UBR4
# getting Hugo data for ZYG11B
# gene names: ['CDCA5', 'DBR1', 'MPLKIP', 'MYCBP2', 'PDS5B', 'PMEPA1', 'RAD21', 'SMC1A', 'SMC3', 'SPATA20', 'TSEN54', 'UBR4', 'ZYG11B']
# gene name = CDCA5
# uniprot_ids = ['Q96FF9']
# querying uniprot id Q96FF9
# gene name = DBR1
# uniprot_ids = ['Q9UK59']
# querying uniprot id Q9UK59
# gene name = MPLKIP
# uniprot_ids = ['Q8TAP9']
# querying uniprot id Q8TAP9
# gene name = MYCBP2
# uniprot_ids = ['O75592']
# querying uniprot id O75592
# gene name = PDS5B
# uniprot_ids = ['Q9NTI5']
# querying uniprot id Q9NTI5
# gene name = PMEPA1
# uniprot_ids = ['Q969W9']
# querying uniprot id Q969W9
# gene name = RAD21
# uniprot_ids = ['O60216']
# querying uniprot id O60216
# gene name = SMC1A
# uniprot_ids = ['Q14683']
# querying uniprot id Q14683
# gene name = SMC3
# uniprot_ids = ['Q9UQE7']
# querying uniprot id Q9UQE7
# gene name = SPATA20
# uniprot_ids = ['Q8TB22']
# querying uniprot id Q8TB22
# gene name = TSEN54
# uniprot_ids = ['Q7Z6J9']
# querying uniprot id Q7Z6J9
# gene name = UBR4
# uniprot_ids = ['Q5T4S7']
# querying uniprot id Q5T4S7
# gene name = ZYG11B
# uniprot_ids = ['Q9C0D3']
# querying uniprot id Q9C0D3

# %%
# workdir = 'Projects/cellmaps_annotate_hierarchy/cellmaps_annotate_hierarchy/'
# sig_sys_txt = '/cellar/users/mhu/Projects/U2OS_MuSIC/Mutation/hisig_res/April2023_V1.1/pan_pediatric/042623_sig_systems_q0.3.txt'


# import os
# import json
# import sys
# from file_io import get_model_directory_path,write_system_json, get_root_path
# from model_cx2 import get_system, get_genes

# from hugo import get_hugo_data
# from file_io import read_system_json, write_system_tsv
# import pandas as pd
# from io import StringIO
# from uniprot import get_uniprot_data_for_system, summarize_uniprot_features, summarized_uniprot_features_to_tsv

# os.environ["MODEL_ANNOTATION_ROOT"] = workdir

# # load gene symbol menta data 

# ## load the model 
# model_name = "MuSIC2_Maps"
# version = "v1.1_April2023"
# model_cx2_filename = "MuSIC2_v1.1_April2023.cx2"
# print(get_model_directory_path(model_name, version))

# model_path = os.path.join(get_model_directory_path(model_name, version), model_cx2_filename)

# with open(model_path, encoding='utf-8') as f:
#     data = f.read()
#     model = json.loads(data)
# # print(model)

# # load the system list
# with open(sig_sys_txt, 'r') as f:
#     systems = f.readlines()
# # get genes for each system
# for system_name in systems:
#     # select systems
#     system = get_system(model, system_name)
#     # system
#     write_system_json(system, model_name, version, system_name, "data", get_root_path())
#     genes = get_genes(system)
#     # print(f'{system_name}: {genes}')
#     # for gene in genes:
#     #     print(gene)

#     for gene in genes: 

#     if len(genes)<50: # right now checking small systems
#         ## convert all gene names to the most up-to-date gene symbol
#         # get hugo data
#         hugo_data = get_hugo_data(system)

#         write_system_json(hugo_data, model_name, version, system_name, "hugo", get_root_path())

#         hugo_data = read_system_json(model_name, version, system_name, "hugo", get_root_path())
#         # get uniprot data
#         uniprot_data = get_uniprot_data_for_system(system, hugo_data=hugo_data)
#         write_system_json(uniprot_data, model_name, version, system_name, "uniprot", get_root_path())
            
#         # get uniprot summary
#         summarized_features = summarize_uniprot_features(uniprot_data)
#         tsv_data = summarized_uniprot_features_to_tsv(summarized_features)
#         write_system_tsv(tsv_data, model_name, version, system_name, "uniprot_summary", get_root_path())
# Out:
# /cellar/users/mhu/Projects/cellmaps_annotate_hierarchy/cellmaps_annotate_hierarchy/MuSIC2_Maps/v1.1_April2023
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/Projects/cellmaps_annotate_hierarchy/cellmaps_annotate_hierarchy/create_prompt_for_MuSIC2.py in <module>
#     111         # system
#     112         write_system_json(system, model_name, version, system_name, "data", get_root_path())
# --> 113         genes = get_genes(system)
#     114         # print(f'{system_name}: {genes}')
#     115         # for gene in genes:
#
# ~/Projects/cellmaps_annotate_hierarchy/cellmaps_annotate_hierarchy/model_cx2.py in get_genes(system)
#      49
#      50 def get_genes(system):
# ---> 51     genes_attribute = system.get("genes_attribute")
#      52     if genes_attribute is None:
#      53         genes_attribute = "MemberList"
#
# AttributeError: 'NoneType' object has no attribute 'get'
